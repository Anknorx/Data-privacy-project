# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def correlation(dataset, threshold):
        col_corr = set()
        corr_matrix = dataset.corr()
        for i in range(len(corr_matrix.columns)):
            for j in range(i):
                if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                    colname = corr_matrix.columns[i]  # getting the name of column
                    col_corr.add(colname)
        return col_corr

# %%
from sklearn.model_selection import train_test_split
df=pd.read_csv('data3.csv')
X=df.drop(labels=['pdays'], axis=1)
y=df['pdays']
# separate dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(labels=['pdays'], axis=1),
    df['pdays'],
    test_size=0.3,
    random_state=0)

# %%
import seaborn as sns
corrmat = X_train.corr()
fig, ax=plt.subplots()
fig.set_size_inches(11,11)
sns.heatmap(corrmat,annot=True, cmap=plt.cm.CMRmap_r)
# Out:
# <AxesSubplot:>

# %%
corr_features =correlation(X_train,0.7)
len(set(corr_features))
# Out:
# 3

# %%
corr_features
# Out:
# {'cons.price.idx', 'euribor3m', 'nr.employed'}

# %%
X_train.drop(corr_features,axis=1)
# Out:
#             Name  age          job   marital            education  default  \
# 31880   Darshawn   37   management   married    university.degree  unknown
# 38177     Lindey   54   management  divorced    university.degree  unknown
# 2459        Niki   49  blue-collar   married             basic.9y  unknown
# 756    Nicolette   30     services   married    university.degree       no
# 11275     Ayrika   23  blue-collar    single             basic.9y       no
# ...          ...  ...          ...       ...                  ...      ...
# 20757     Terran   52       admin.  divorced    university.degree       no
# 32103      Georg   56   management  divorced    university.degree       no
# 30403      Tijon   29       admin.    single  professional.course       no
# 21243     Nevaeh   35    housemaid    single  professional.course       no
# 2732       Nidhi   52       admin.   married          high.school       no
#
#        balance  housing     loan    contact month day_of_week  duration  \
# 31880     6533       no      yes   cellular   may         thu       195
# 38177     1039      yes       no   cellular   oct         thu       214
# 2459      -204       no       no  telephone   may         tue       813
# 756       3754      yes       no  telephone   may         wed        51
# 11275     2571       no       no  telephone   jun         thu       359
# ...        ...      ...      ...        ...   ...         ...       ...
# 20757     4367       no       no   cellular   aug         wed       559
# 32103     -145       no       no   cellular   may         fri       166
# 30403      995       no       no   cellular   apr         thu       427
# 21243      750      yes      yes   cellular   aug         mon       111
# 2732        57  unknown  unknown  telephone   may         wed       132
#
#        campaign  previous     poutcome  emp.var.rate  cons.conf.idx youtcome
# 31880         1         0  nonexistent          -1.8          -46.2       no
# 38177         1         0  nonexistent          -3.4          -26.9       no
# 2459          2         0  nonexistent           1.1          -36.4       no
# 756           3         0  nonexistent           1.1          -36.4       no
# 11275         1         0  nonexistent           1.4          -41.8       no
# ...         ...       ...          ...           ...            ...      ...
# 20757         2         0  nonexistent           1.4          -36.1       no
# 32103         1         0  nonexistent          -1.8          -46.2       no
# 30403         3         0  nonexistent          -1.8          -47.1      yes
# 21243         1         0  nonexistent           1.4          -36.1       no
# 2732          1         0  nonexistent           1.1          -36.4       no
#
# [28831 rows x 19 columns]

# %%
X_train.drop(corr_features,axis=1)
# Out:
#             Name  age          job   marital            education  default  \
# 31880   Darshawn   37   management   married    university.degree  unknown
# 38177     Lindey   54   management  divorced    university.degree  unknown
# 2459        Niki   49  blue-collar   married             basic.9y  unknown
# 756    Nicolette   30     services   married    university.degree       no
# 11275     Ayrika   23  blue-collar    single             basic.9y       no
# ...          ...  ...          ...       ...                  ...      ...
# 20757     Terran   52       admin.  divorced    university.degree       no
# 32103      Georg   56   management  divorced    university.degree       no
# 30403      Tijon   29       admin.    single  professional.course       no
# 21243     Nevaeh   35    housemaid    single  professional.course       no
# 2732       Nidhi   52       admin.   married          high.school       no
#
#        balance  housing     loan    contact month day_of_week  duration  \
# 31880     6533       no      yes   cellular   may         thu       195
# 38177     1039      yes       no   cellular   oct         thu       214
# 2459      -204       no       no  telephone   may         tue       813
# 756       3754      yes       no  telephone   may         wed        51
# 11275     2571       no       no  telephone   jun         thu       359
# ...        ...      ...      ...        ...   ...         ...       ...
# 20757     4367       no       no   cellular   aug         wed       559
# 32103     -145       no       no   cellular   may         fri       166
# 30403      995       no       no   cellular   apr         thu       427
# 21243      750      yes      yes   cellular   aug         mon       111
# 2732        57  unknown  unknown  telephone   may         wed       132
#
#        campaign  previous     poutcome  emp.var.rate  cons.conf.idx youtcome
# 31880         1         0  nonexistent          -1.8          -46.2       no
# 38177         1         0  nonexistent          -3.4          -26.9       no
# 2459          2         0  nonexistent           1.1          -36.4       no
# 756           3         0  nonexistent           1.1          -36.4       no
# 11275         1         0  nonexistent           1.4          -41.8       no
# ...         ...       ...          ...           ...            ...      ...
# 20757         2         0  nonexistent           1.4          -36.1       no
# 32103         1         0  nonexistent          -1.8          -46.2       no
# 30403         3         0  nonexistent          -1.8          -47.1      yes
# 21243         1         0  nonexistent           1.4          -36.1       no
# 2732          1         0  nonexistent           1.1          -36.4       no
#
# [28831 rows x 19 columns]
